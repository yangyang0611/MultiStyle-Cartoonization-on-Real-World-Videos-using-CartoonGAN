# %% [markdown]
# # CartoonGAN
#
# This notebook contains the implementation of the cartoon GAN model. It is implemented with PyTorch. See README [here](https://github.com/TobiasSunderdiek/cartoon-gan/blob/master/README.md) for more details.

# %% [markdown]
# ## Generate dataset

# %% [markdown]
# ## Transfer data via google drive
# - all image data in this notebook is expected to be zipped to files on local computer as described in README of this project [here](https://github.com/TobiasSunderdiek/cartoon-gan/blob/master/README.md)
# - create folder `cartoonGAN` in `My Drive` in google drive
# - copy .zip-files `coco.zip`, `safebooru.zip` and `safebooru_smoothed.zip` to google drive `My Drive`/`cartoonGAN`
# - mount google drive in this notebook by executing cell below

# %%
from google.colab import drive
drive.mount('/content/data')
# Out:
# Drive already mounted at /content/data; to attempt to forcibly remount, call drive.mount("/content/data", force_remount=True).

# %% [markdown]
# ### cartoons images
#
# - cartoon images are located in file `content/data/My Drive/cartoonGAN/safebooru.zip` of this notebook
# - extract images and place in folder `cartoons` by executing cell below

# %%
# !mkdir cartoons
# !mkdir cartoons/1
# !unzip -n -q /content/data/My\ Drive/cartoonGAN/safebooru.zip -d cartoons/1/ #extract to subfolder due to DataLoader needs subdirectories

# %% [markdown]
# ##### data-loader

# %%
import torch
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
from torchvision import transforms
from torch.utils.data import random_split
import math

image_size = 256
batch_size = 16

transformer = transforms.Compose([
    transforms.CenterCrop(image_size),
    transforms.ToTensor() # ToTensor() changes the range of the values from [0, 255] to [0.0, 1.0]
])

cartoon_dataset = ImageFolder('/content/data/MyDrive/AI_Final_Project/cartoons/', transformer)
len_training_set = math.floor(len(cartoon_dataset) * 0.9)
len_valid_set = len(cartoon_dataset) - len_training_set

training_set, _ = random_split(cartoon_dataset, (len_training_set, len_valid_set))
cartoon_image_dataloader_train = DataLoader(training_set, batch_size, shuffle=True, num_workers=0)

# %% [markdown]
# #### show examples

# %%
import matplotlib.pyplot as plt
import numpy as np

def show_sample_image(dataloader):
  iterator = iter(dataloader)
  sample_batch, _ = iterator.next()
  first_sample_image_of_batch = sample_batch[0]
  print(first_sample_image_of_batch.size())
  print("Current range: {} to {}".format(first_sample_image_of_batch.min(), first_sample_image_of_batch.max()))
  plt.imshow(np.transpose(first_sample_image_of_batch.numpy(), (1, 2, 0)))

show_sample_image(cartoon_image_dataloader_train)
# Out:
# torch.Size([3, 256, 256])
# Current range: 0.0 to 0.9764705896377563

# %% [markdown]
# ### edge-smoothed cartoons images
#
# - edge-smoothed cartoon images are located in file `content/data/My Drive/cartoonGAN/safebooru_smoothed.zip` of this notebook
# - extract images and place in folder `cartoons_smoothed` by executing cell below

# %%
# !mkdir cartoons_smoothed
# !mkdir cartoons_smoothed/1
# !unzip -n -q /content/data/My\ Drive/cartoonGAN/safebooru_smoothed.zip -d cartoons_smoothed/1/ #extract to subfolder due to DataLoader needs subdirectories

# %% [markdown]
# ##### data-loader
#
# same configuration as cartoon data loader above

# %%
smoothed_cartoon_dataset = ImageFolder('/content/data/MyDrive/AI_Final_Project/cartoons_smoothed/', transformer)
len_training_set = math.floor(len(smoothed_cartoon_dataset) * 0.9)
len_valid_set = len(smoothed_cartoon_dataset) - len_training_set
training_set, _ = random_split(smoothed_cartoon_dataset, (len_training_set, len_valid_set))
smoothed_cartoon_image_dataloader_train = DataLoader(training_set, batch_size, shuffle=True, num_workers=0)

# %% [markdown]
# #### show examples

# %%
show_sample_image(smoothed_cartoon_image_dataloader_train)
# Out:
# torch.Size([3, 256, 256])
# Current range: 0.0 to 1.0

# %% [markdown]
# ### photos

# %% [markdown]
# - photos are located in file `content/data/My Drive/cartoonGAN/coco.zip` of this notebook
# - extract images and place in folder `photos` by executing cell below

# %%
# !mkdir photos
# !mkdir photos/1
# !unzip -n -q /content/data/My\ Drive/cartoonGAN/coco.zip -d photos/1 #extract to subfolder due to DataLoader needs subdirectories

# %% [markdown]
# ##### data-loader
# same configuration as cartoon data loader above

# %%
photo_dataset = ImageFolder('/content/data/MyDrive/AI_Final_Project/photos/', transformer)
len_training_set = math.floor(len(photo_dataset) * 0.9)
len_valid_set = len(photo_dataset) - len_training_set
training_set, validation_set = random_split(photo_dataset, (len_training_set, len_valid_set))
photo_dataloader_train = DataLoader(training_set, batch_size, shuffle=True, num_workers=0)
photo_dataloader_valid = DataLoader(validation_set, batch_size, shuffle=True, num_workers=0)

# %% [markdown]
# #### show examples

# %%
show_sample_image(photo_dataloader_train)
# Out:
# torch.Size([3, 256, 256])
# Current range: 0.0 to 1.0

# %% [markdown]
# ## Setup tensorboard
#
# Use tensorboard to have an eye on weights and losses.

# %%
# !mkdir /content/data/My\ Drive/cartoonGAN/tensorboard/

# %%
# %tensorflow_version 1.x

from torch.utils.tensorboard import SummaryWriter

tensorboard_logdir = '/content/data/MyDrive/AI_Final_Project/tensorboard'
writer = SummaryWriter(tensorboard_logdir)
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# ###Generator

# %%
import torch.nn as nn
import torch.nn.functional as F
from torch import sigmoid

class ResidualBlock(nn.Module):
  def __init__(self):
    super(ResidualBlock, self).__init__()
    self.conv_1 = nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1)
    self.conv_2 = nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1)
    self.norm_1 = nn.BatchNorm2d(256)
    self.norm_2 = nn.BatchNorm2d(256)

  def forward(self, x):
    output = self.norm_2(self.conv_2(F.relu(self.norm_1(self.conv_1(x)))))
    return output + x #ES

class Generator(nn.Module):
    def __init__(self):
      super(Generator, self).__init__()
      self.conv_1 = nn.Conv2d(in_channels=3, out_channels=64, kernel_size=7, stride=1, padding=3)
      self.norm_1 = nn.BatchNorm2d(64)
      
      # down-convolution #
      self.conv_2 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=2, padding=1)
      self.conv_3 = nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1)
      self.norm_2 = nn.BatchNorm2d(128)
      
      self.conv_4 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, stride=2, padding=1)
      self.conv_5 = nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1)
      self.norm_3 = nn.BatchNorm2d(256)
      
      # residual blocks #
      residualBlocks = []
      for l in range(8):
        residualBlocks.append(ResidualBlock())
      self.res = nn.Sequential(*residualBlocks)
      
      # up-convolution #
      self.conv_6 = nn.ConvTranspose2d(in_channels=256, out_channels=128, kernel_size=3, stride=2, padding=1, output_padding=1)
      self.conv_7 = nn.ConvTranspose2d(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1)
      self.norm_4 = nn.BatchNorm2d(128)

      self.conv_8 = nn.ConvTranspose2d(in_channels=128, out_channels=64, kernel_size=3, stride=2, padding=1, output_padding=1)
      self.conv_9 = nn.ConvTranspose2d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=1)
      self.norm_5 = nn.BatchNorm2d(64)
      
      self.conv_10 = nn.Conv2d(in_channels=64, out_channels=3, kernel_size=7, stride=1, padding=3)

    def forward(self, x):
      x = F.relu(self.norm_1(self.conv_1(x)))
      
      x = F.relu(self.norm_2(self.conv_3(self.conv_2(x))))
      x = F.relu(self.norm_3(self.conv_5(self.conv_4(x))))
      
      x = self.res(x)
      x = F.relu(self.norm_4(self.conv_7(self.conv_6(x))))
      x = F.relu(self.norm_5(self.conv_9(self.conv_8(x))))

      x = self.conv_10(x)

      x = sigmoid(x)

      return x

# %%
G = Generator()
print(G)
# Out:
# Generator(
#   (conv_1): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#   (norm_1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv_2): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (conv_3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm_2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv_4): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (conv_5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm_3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (res): Sequential(
#     (0): ResidualBlock(
#       (conv_1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm_1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm_2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ResidualBlock(
#       (conv_1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm_1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm_2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): ResidualBlock(
#       (conv_1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm_1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm_2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): ResidualBlock(
#       (conv_1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm_1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm_2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): ResidualBlock(
#       (conv_1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm_1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm_2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): ResidualBlock(
#       (conv_1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm_1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm_2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (6): ResidualBlock(
#       (conv_1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm_1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm_2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (7): ResidualBlock(
#       (conv_1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm_1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm_2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv_6): ConvTranspose2d(256, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   (conv_7): ConvTranspose2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm_4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv_8): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   (conv_9): ConvTranspose2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm_5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv_10): Conv2d(64, 3, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
# )

# %% [markdown]
# ### Discriminator

# %%
class Discriminator(nn.Module):
  def __init__(self):
     super(Discriminator, self).__init__()
     self.conv_1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, stride=1, padding=1)
      
     self.conv_2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=2, padding=1)
     self.conv_3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1)
     self.norm_1 = nn.BatchNorm2d(128)
      
     self.conv_4 = nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, stride=2, padding=1)
     self.conv_5 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1)
     self.norm_2 = nn.BatchNorm2d(256)
    
     self.conv_6 = nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1)
     self.norm_3 = nn.BatchNorm2d(256)
    
     self.conv_7 = nn.Conv2d(in_channels=256, out_channels=1, kernel_size=3, stride=1, padding=1)

  def forward(self, x):
    x = F.leaky_relu(self.conv_1(x))
    x = F.leaky_relu(self.norm_1(self.conv_3(F.leaky_relu(self.conv_2(x)))), negative_slope=0.2)
    x = F.leaky_relu(self.norm_2(self.conv_5(F.leaky_relu(self.conv_4(x)))), negative_slope=0.2)
    x = F.leaky_relu(self.norm_3(self.conv_6(x)), negative_slope=0.2)
    x = self.conv_7(x)
    x = sigmoid(x)
    
    return x

# %%
D = Discriminator()
print(D)
# Out:
# Discriminator(
#   (conv_1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_2): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (conv_3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm_1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv_4): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (conv_5): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm_2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv_6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm_3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv_7): Conv2d(256, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )

# %% [markdown]
# ### use device CPU or GPU

# %%
import torch

device = torch.device('cpu')

if torch.cuda.is_available():
  device = torch.device('cuda')
  print("Train on GPU.")
else:
  print("No cuda available")

G.to(device)
D.to(device)
# Out:
# Train on GPU.
# Discriminator(
#   (conv_1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_2): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (conv_3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm_1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv_4): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (conv_5): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm_2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv_6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm_3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv_7): Conv2d(256, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )

# %% [markdown]
# ### VGG-16
# Load already downloaded vgg-16 weights from drive, or download and save to drive.

# %%
from torchvision import models

path_to_pretrained_vgg16 = '/content/data/MyDrive/AI_Final_Project/vgg16-pretrained.pth'

#try:
 # pretrained = torch.load(path_to_pretrained_vgg16)
  #vgg16 = models.vgg16(pretrained=False)
  #vgg16.load_state_dict(pretrained)
  #vgg16 = vgg16.to(device)
#except FileNotFoundError:
vgg16 = models.vgg16(pretrained=True)
torch.save(vgg16, path_to_pretrained_vgg16)
vgg16 = vgg16.to(device) # Credits to bdlneto (https://github.com/bdlneto) https://github.com/TobiasSunderdiek/cartoon-gan/issues/5 for finding this issue and testing the new version
print(vgg16)

# due VGG16 has 5 pooling-layer, I assume conv4_4 is the 4th pooling layer
# (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
feature_extractor = vgg16.features[:24]
for param in feature_extractor.parameters():
  param.require_grad = False

print(feature_extractor)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): ReLU(inplace=True)
#   (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (3): ReLU(inplace=True)
#   (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (6): ReLU(inplace=True)
#   (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (8): ReLU(inplace=True)
#   (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): ReLU(inplace=True)
#   (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (13): ReLU(inplace=True)
#   (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (15): ReLU(inplace=True)
#   (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (18): ReLU(inplace=True)
#   (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (20): ReLU(inplace=True)
#   (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (22): ReLU(inplace=True)
#   (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# )

# %% [markdown]
# ### Two loss functions
#
# - discriminator loss
# - generator initialization phase loss and generator loss

# %%
from torchvision import models
from torch.nn import BCELoss

class DiscriminatorLoss(torch.nn.Module):
  def __init__(self):
      super(DiscriminatorLoss, self).__init__()
      self.bce_loss = BCELoss()

  def forward(self, discriminator_output_of_cartoon_input,
              discriminator_output_of_cartoon_smoothed_input,
              discriminator_output_of_generated_image_input,
              epoch,
              write_to_tensorboard=False):

    return self._adversarial_loss(discriminator_output_of_cartoon_input,
                     discriminator_output_of_cartoon_smoothed_input,
                     discriminator_output_of_generated_image_input,
                     epoch,
                     write_to_tensorboard)

  def _adversarial_loss(self, discriminator_output_of_cartoon_input,
                     discriminator_output_of_cartoon_smoothed_input,
                     discriminator_output_of_generated_image_input,
                     epoch,
                     write_to_tensorboard):

    # define ones and zeros here instead within __init__ due to have same shape as input
    # due to testing different batch_sizes, sometimes the "last batch" has < batch_size elements
    actual_batch_size = discriminator_output_of_cartoon_input.size()[0]
    zeros = torch.zeros([actual_batch_size, 1, 64, 64]).to(device)
    ones = torch.ones([actual_batch_size, 1, 64, 64]).to(device)

    d_loss_cartoon = self.bce_loss(discriminator_output_of_cartoon_input, ones)
    d_loss_cartoon_smoothed = self.bce_loss(discriminator_output_of_cartoon_smoothed_input, zeros)
    d_loss_generated_input = self.bce_loss(discriminator_output_of_generated_image_input, zeros)

    d_loss = d_loss_cartoon + d_loss_cartoon_smoothed + d_loss_generated_input

    if write_to_tensorboard:
      writer.add_scalar('d_loss_cartoon', d_loss_cartoon,epoch)
      writer.add_scalar('d_loss_cartoon_smoothed', d_loss_cartoon_smoothed, epoch)
      writer.add_scalar('d_loss_generated_input', d_loss_generated_input, epoch)
      writer.add_scalar('d_loss', d_loss, epoch)

    return d_loss

# %%
class GeneratorLoss(torch.nn.Module):
  def __init__(self):
      super(GeneratorLoss, self).__init__()
      self.w = 0.00001
      self.bce_loss = BCELoss()
      self.feature_extractor = vgg16.features[:24]
      for param in self.feature_extractor.parameters():
        param.require_grad = False

  def forward(self, discriminator_output_of_generated_image_input,
              generator_input,
              generator_output,
              epoch,
              is_init_phase=False,
              write_to_tensorboard=False):
    if is_init_phase:
      g_content_loss = self._content_loss(generator_input, generator_output)
      g_adversarial_loss = 0.0
      g_loss = g_content_loss
    else:
      g_adversarial_loss = self._adversarial_loss_generator_part_only(discriminator_output_of_generated_image_input)
      g_content_loss = self._content_loss(generator_input, generator_output)
      g_loss = g_adversarial_loss + self.w * g_content_loss

    if write_to_tensorboard:
      writer.add_scalar('g_adversarial_loss', g_adversarial_loss, epoch)
      writer.add_scalar('g_content_loss', g_content_loss, epoch)
      writer.add_scalar('g_loss', g_loss, epoch)

    return g_loss

  def _adversarial_loss_generator_part_only(self, discriminator_output_of_generated_image_input):
    actual_batch_size = discriminator_output_of_generated_image_input.size()[0]
    ones = torch.ones([actual_batch_size, 1, 64, 64]).to(device)
    return self.bce_loss(discriminator_output_of_generated_image_input, ones)

  def _content_loss(self, generator_input, generator_output):
    return (self.feature_extractor(generator_output) - self.feature_extractor(generator_input)).norm(p=1)

# %%
discriminatorLoss = DiscriminatorLoss()
generatorLoss = GeneratorLoss()

# %% [markdown]
# ## Optimizer

# %%
import torch.optim as optim

lr = 0.0002
beta1 = 0.5
beta2 = 0.999

d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])

# %% [markdown]
# ## Saving
# To make training resumeable, I save some checkpoints to google drive and load them, if existing, before run the training.
#
# I also save weights and bias from generator and discriminator to tensorboard.
#
# For checking some intermediate images of the generator, I save them to google drive.

# %%
# !mkdir /content/data/My\ Drive/cartoonGAN/checkpoints/
# !mkdir -p /content/data/My\ Drive/cartoonGAN/intermediate_results/training/
intermediate_results_training_path = "/content/data/MyDrive/AI_Final_Project/intermediate_results/training/"

# %%
def save_training_result(input, output):
  # input/output has batch-size number of images, get first one and detach from tensor
  image_input = input[0].detach().cpu().numpy()
  image_output = output[0].detach().cpu().numpy()
  # transponse image from torch.Size([3, 256, 256]) to (256, 256, 3)
  image_input = np.transpose(image_input, (1, 2, 0))
  image_output = np.transpose(image_output, (1, 2, 0))

  # generate filenames as timestamp, this orders the output by time
  filename = str(int(time.time()))
  path_input = intermediate_results_training_path + filename + "_input.jpg"
  path_output = intermediate_results_training_path + filename + ".jpg"
  plt.imsave(path_input, image_input)
  plt.imsave(path_output, image_output)

# %%
def write_model_weights_and_bias_to_tensorboard(prefix, state_dict, epoch):
  for param in state_dict:
      writer.add_histogram(f"{prefix}_{param}", state_dict[param], epoch)

# %% [markdown]
# ## Training

# %%
import time

def train(_num_epochs, checkpoint_dir, best_valid_loss, epochs_already_done, losses, validation_losses):
  init_epochs = 10
  print_every = 100
  start_time = time.time()

  for epoch in range(_num_epochs - epochs_already_done):
    epoch = epoch + epochs_already_done

    for index, ((photo_images, _), (smoothed_cartoon_images, _), (cartoon_images, _)) in enumerate(zip(photo_dataloader_train, smoothed_cartoon_image_dataloader_train, cartoon_image_dataloader_train)):
      batch_size = photo_images.size(0)
      photo_images = photo_images.to(device)
      smoothed_cartoon_images = smoothed_cartoon_images.to(device)
      cartoon_images = cartoon_images.to(device)

      # train the discriminator
      d_optimizer.zero_grad()
      
      d_of_cartoon_input = D(cartoon_images)
      d_of_cartoon_smoothed_input = D(smoothed_cartoon_images)
      d_of_generated_image_input = D(G(photo_images))

      write_only_one_loss_from_epoch_not_every_batch_loss = (index == 0)

      d_loss = discriminatorLoss(d_of_cartoon_input,
                                 d_of_cartoon_smoothed_input,
                                 d_of_generated_image_input,
                                 epoch,
                                 write_to_tensorboard=write_only_one_loss_from_epoch_not_every_batch_loss)

      d_loss.backward()
      d_optimizer.step()

      # train the generator
      g_optimizer.zero_grad()

      g_output = G(photo_images)

      d_of_generated_image_input = D(g_output)

      if epoch < init_epochs:
        # init
        init_phase = True
      else:
        # train
        init_phase = False

      g_loss = generatorLoss(d_of_generated_image_input,
                              photo_images,
                              g_output,
                              epoch,
                              is_init_phase=init_phase,
                              write_to_tensorboard=write_only_one_loss_from_epoch_not_every_batch_loss)

      g_loss.backward()
      g_optimizer.step()

      if (index % print_every) == 0:
        losses.append((d_loss.item(), g_loss.item()))
        now = time.time()
        current_run_time = now - start_time
        start_time = now
        print("Epoch {}/{} | d_loss {:6.4f} | g_loss {:6.4f} | time {:2.0f}s | total no. of losses {}".format(epoch+1, _num_epochs, d_loss.item(), g_loss.item(), current_run_time, len(losses)))
    
    # write to tensorboard
      #write_model_weights_and_bias_to_tensorboard('D', D.state_dict(), epoch)
      #write_model_weights_and_bias_to_tensorboard('G', G.state_dict(), epoch)
    # save some intermediate results during training
    save_training_result(photo_images, g_output)

    # validate
    with torch.no_grad():
      D.eval()
      G.eval()

      for batch_index, (photo_images, _) in enumerate(photo_dataloader_valid):
        photo_images = photo_images.to(device)

        g_output = G(photo_images)
        d_of_generated_image_input = D(g_output)
        g_valid_loss = generatorLoss(d_of_generated_image_input,
                                      photo_images,
                                      g_output,
                                      epoch,
                                      is_init_phase=init_phase,
                                      write_to_tensorboard=write_only_one_loss_from_epoch_not_every_batch_loss)

        if batch_index % print_every == 0:
          validation_losses.append(g_valid_loss.item())
          now = time.time()
          current_run_time = now - start_time
          start_time = now
          print("Epoch {}/{} | validation loss {:6.4f} | time {:2.0f}s | total no. of losses {}".format(epoch+1, _num_epochs, g_valid_loss.item(), current_run_time, len(validation_losses)))

    D.train()
    G.train()
    
    if(g_valid_loss.item() < best_valid_loss):
      print("Generator loss improved from {} to {}".format(best_valid_loss, g_valid_loss.item()))
      best_valid_loss = g_valid_loss.item()
  
    # save checkpoint
    checkpoint = {'g_valid_loss': g_valid_loss.item(),
                  'best_valid_loss': best_valid_loss,
                  'losses': losses,
                  'validation_losses': validation_losses,
                  'last_epoch': epoch+1,
                  'd_state_dict': D.state_dict(),
                  'g_state_dict': G.state_dict(),
                  'd_optimizer_state_dict': d_optimizer.state_dict(),
                  'g_optimizer_state_dict': g_optimizer.state_dict()
                }
    print("Save checkpoint for validation loss of {}".format(g_valid_loss.item()))
    torch.save(checkpoint, checkpoint_dir + '/checkpoint_epoch_{:03d}.pth'.format(epoch+1))
    if(best_valid_loss == g_valid_loss.item()):
      print("Overwrite best checkpoint")
      torch.save(checkpoint, checkpoint_dir + '/best_checkpoint.pth')
    
  return losses, validation_losses

# %%
from os import listdir

checkpoint_dir = '/content/data/MyDrive/AI_Final_Project/checkpoints'
checkpoints = listdir(checkpoint_dir)
num_epochs = 200 + 10 # training + init phase
epochs_already_done = 0
best_valid_loss = math.inf
losses = []
validation_losses = []

if(len(checkpoints) > 0):
  last_checkpoint = sorted(checkpoints)[-1]
  checkpoint = torch.load(checkpoint_dir + '/' + last_checkpoint, map_location=torch.device(device))
  best_valid_loss = checkpoint['best_valid_loss']
  epochs_already_done = checkpoint['last_epoch']
  losses = checkpoint['losses']
  validation_losses = checkpoint['validation_losses']
  
  D.load_state_dict(checkpoint['d_state_dict'])
  G.load_state_dict(checkpoint['g_state_dict'])
  d_optimizer.load_state_dict(checkpoint['d_optimizer_state_dict'])
  g_optimizer.load_state_dict(checkpoint['g_optimizer_state_dict'])
  print('Load checkpoint {} with g_valid_loss {}, best_valid_loss {}, {} epochs and total no of losses {}'.format(last_checkpoint, checkpoint['g_valid_loss'], best_valid_loss, epochs_already_done, len(losses)))

# %%
import time

def train(_num_epochs, checkpoint_dir, best_valid_loss, epochs_already_done, losses, validation_losses):
  init_epochs = 10
  print_every = 10
  start_time = time.time()

  for epoch in range(_num_epochs - epochs_already_done):
    epoch = epoch + epochs_already_done
    print("---------------- Epoch {} ----------------".format(epoch+1))
    losses_this_epoch=[]
    for index, ((photo_images, _), (smoothed_cartoon_images, _), (cartoon_images, _)) in enumerate(zip(photo_dataloader_train, smoothed_cartoon_image_dataloader_train, cartoon_image_dataloader_train)):
      batch_size = photo_images.size(0)
      photo_images = photo_images.to(device)
      smoothed_cartoon_images = smoothed_cartoon_images.to(device)
      cartoon_images = cartoon_images.to(device)

      # train the discriminator
      d_optimizer.zero_grad()
      
      d_of_cartoon_input = D(cartoon_images)
      d_of_cartoon_smoothed_input = D(smoothed_cartoon_images)
      d_of_generated_image_input = D(G(photo_images))

      write_only_one_loss_from_epoch_not_every_batch_loss = (index == 0)

      d_loss = discriminatorLoss(d_of_cartoon_input,
                                 d_of_cartoon_smoothed_input,
                                 d_of_generated_image_input,
                                 epoch,
                                 write_to_tensorboard=write_only_one_loss_from_epoch_not_every_batch_loss)

      d_loss.backward()
      d_optimizer.step()

      # train the generator
      g_optimizer.zero_grad()

      g_output = G(photo_images)

      d_of_generated_image_input = D(g_output)

      if epoch < init_epochs:
        # init
        init_phase = True
      else:
        # train
        init_phase = False

      g_loss = generatorLoss(d_of_generated_image_input,
                              photo_images,
                              g_output,
                              epoch,
                              is_init_phase=init_phase,
                              write_to_tensorboard=write_only_one_loss_from_epoch_not_every_batch_loss)

      g_loss.backward()
      g_optimizer.step()

      if (index % print_every) == 0:
        losses_this_epoch.append((d_loss.item(), g_loss.item()))
        losses.append((d_loss.item(), g_loss.item()))
        now = time.time()
        current_run_time = now - start_time
        start_time = now
        print("[{:3d}/{}] | d_loss {:6.4f} | g_loss {:6.4f} | avg_d_loss {:6.4f} | avg_g_loss {:6.4f} | time {:2.0f}s | total no. of losses {}".format(index,len(photo_dataloader_train), d_loss.item(), g_loss.item(),sum(i for i,j in losses_this_epoch)/len(losses_this_epoch),sum(j for i,j in losses_this_epoch)/len(losses_this_epoch), current_run_time, len(losses_this_epoch)))
    print("Epoch {}/{} | avg_d_loss {:6.4f} | avg_g_loss {:6.4f}".format(epoch+1, _num_epochs,sum(i for i,j in losses_this_epoch)/len(losses_this_epoch),sum(j for i,j in losses_this_epoch)/len(losses_this_epoch)))
    # write to tensorboard
      #write_model_weights_and_bias_to_tensorboard('D', D.state_dict(), epoch)
      #write_model_weights_and_bias_to_tensorboard('G', G.state_dict(), epoch)
    # save some intermediate results during training
    save_training_result(photo_images, g_output)
    print("---------------- Testing ----------------")
    # validate
    with torch.no_grad():
      D.eval()
      G.eval()
      validation_losses_this_epoch=[]
      for batch_index, (photo_images, _) in enumerate(photo_dataloader_valid):
        photo_images = photo_images.to(device)

        g_output = G(photo_images)
        d_of_generated_image_input = D(g_output)
        g_valid_loss = generatorLoss(d_of_generated_image_input,
                                      photo_images,
                                      g_output,
                                      epoch,
                                      is_init_phase=init_phase,
                                      write_to_tensorboard=write_only_one_loss_from_epoch_not_every_batch_loss)
        
        if batch_index % print_every == 0:
          validation_losses_this_epoch.append(g_valid_loss.item())
          validation_losses.append(g_valid_loss.item())
          now = time.time()
          current_run_time = now - start_time
          start_time = now
          print("[{:3d}/{}] | validation_loss {:6.4f} | avg_validation_loss {:6.4f} | time {:2.0f}s | total no. of losses {}".format(batch_index,len(photo_dataloader_valid), g_valid_loss.item(), sum(validation_losses_this_epoch)/len(validation_losses_this_epoch), current_run_time, len(validation_losses_this_epoch)))
      print("Epoch {}/{} | avg_validation loss {:6.4f} | time {:2.0f}s | total no. of losses {}".format(epoch+1, _num_epochs, sum(validation_losses_this_epoch)/len(validation_losses_this_epoch), current_run_time, len(validation_losses_this_epoch)))

    D.train()
    G.train()
    
    avg_validation_loss=sum(validation_losses_this_epoch)/len(validation_losses_this_epoch)

    if(avg_validation_loss < best_valid_loss):
      print("Generator loss improved from {} to {}".format(best_valid_loss, avg_validation_loss))
      best_valid_loss = avg_validation_loss
  
    # save checkpoint
    checkpoint = {'g_valid_loss': avg_validation_loss,
                  'best_valid_loss': best_valid_loss,
                  'losses': losses,
                  'validation_losses': validation_losses,
                  'last_epoch': epoch+1,
                  'd_state_dict': D.state_dict(),
                  'g_state_dict': G.state_dict(),
                  'd_optimizer_state_dict': d_optimizer.state_dict(),
                  'g_optimizer_state_dict': g_optimizer.state_dict()
                }
    print("Save checkpoint for validation loss of {}".format(avg_validation_loss))
    torch.save(checkpoint, checkpoint_dir + '/checkpoint_epoch_{:03d}.pth'.format(epoch+1))
    if(best_valid_loss == avg_validation_loss):
      print("Overwrite best checkpoint")
      torch.save(checkpoint, checkpoint_dir + '/best_checkpoint.pth')
    
  return losses, validation_losses


losses, validation_losses = train(num_epochs, checkpoint_dir, best_valid_loss, epochs_already_done, losses, validation_losses)
# Out:
# ---------------- Epoch 1 ----------------
# [  0/225] | d_loss 2.2803 | g_loss 1237195.6250 | avg_d_loss 2.2803 | avg_g_loss 1237195.6250 | time 11s | total no. of losses 1
# [ 10/225] | d_loss 1.7384 | g_loss 1201497.8750 | avg_d_loss 2.0094 | avg_g_loss 1219346.7500 | time 94s | total no. of losses 2
# [ 20/225] | d_loss 1.6085 | g_loss 1105818.3750 | avg_d_loss 1.8757 | avg_g_loss 1181503.9583 | time 102s | total no. of losses 3
# [ 30/225] | d_loss 1.4764 | g_loss 1014736.6875 | avg_d_loss 1.7759 | avg_g_loss 1139812.1406 | time 99s | total no. of losses 4
# [ 40/225] | d_loss 1.4862 | g_loss 1234203.2500 | avg_d_loss 1.7180 | avg_g_loss 1158690.3625 | time 99s | total no. of losses 5
# [ 50/225] | d_loss 1.3427 | g_loss 1040752.1875 | avg_d_loss 1.6554 | avg_g_loss 1139034.0000 | time 97s | total no. of losses 6
# [ 60/225] | d_loss 1.4098 | g_loss 1108279.3750 | avg_d_loss 1.6203 | avg_g_loss 1134640.4821 | time 101s | total no. of losses 7
# [ 70/225] | d_loss 1.0522 | g_loss 1102579.7500 | avg_d_loss 1.5493 | avg_g_loss 1130632.8906 | time 101s | total no. of losses 8
# [ 80/225] | d_loss 1.0457 | g_loss 1204743.3750 | avg_d_loss 1.4934 | avg_g_loss 1138867.3889 | time 96s | total no. of losses 9
# [ 90/225] | d_loss 0.4200 | g_loss 1186946.5000 | avg_d_loss 1.3860 | avg_g_loss 1143675.3000 | time 98s | total no. of losses 10
# [100/225] | d_loss 0.3467 | g_loss 1056933.5000 | avg_d_loss 1.2915 | avg_g_loss 1135789.6818 | time 97s | total no. of losses 11
# [110/225] | d_loss 0.2427 | g_loss 1105795.6250 | avg_d_loss 1.2041 | avg_g_loss 1133290.1771 | time 98s | total no. of losses 12
# [120/225] | d_loss 0.2432 | g_loss 1160467.5000 | avg_d_loss 1.1302 | avg_g_loss 1135380.7404 | time 101s | total no. of losses 13
# [130/225] | d_loss 0.1419 | g_loss 1178706.7500 | avg_d_loss 1.0596 | avg_g_loss 1138475.4554 | time 100s | total no. of losses 14
# [140/225] | d_loss 0.0941 | g_loss 1018022.0000 | avg_d_loss 0.9952 | avg_g_loss 1130445.2250 | time 99s | total no. of losses 15
# [150/225] | d_loss 0.1014 | g_loss 1071686.5000 | avg_d_loss 0.9394 | avg_g_loss 1126772.8047 | time 97s | total no. of losses 16
# [160/225] | d_loss 0.1357 | g_loss 1224440.0000 | avg_d_loss 0.8921 | avg_g_loss 1132517.9338 | time 103s | total no. of losses 17
# [170/225] | d_loss 0.0670 | g_loss 1182372.7500 | avg_d_loss 0.8463 | avg_g_loss 1135287.6458 | time 97s | total no. of losses 18
# [180/225] | d_loss 0.0527 | g_loss 1089160.0000 | avg_d_loss 0.8045 | avg_g_loss 1132859.8750 | time 97s | total no. of losses 19
# [190/225] | d_loss 0.0500 | g_loss 1163664.5000 | avg_d_loss 0.7668 | avg_g_loss 1134400.1062 | time 97s | total no. of losses 20
# [200/225] | d_loss 0.0422 | g_loss 1083993.0000 | avg_d_loss 0.7323 | avg_g_loss 1131999.7679 | time 103s | total no. of losses 21
# [210/225] | d_loss 0.0786 | g_loss 1022978.8125 | avg_d_loss 0.7026 | avg_g_loss 1127044.2699 | time 96s | total no. of losses 22
# [220/225] | d_loss 0.0348 | g_loss 1291325.3750 | avg_d_loss 0.6735 | avg_g_loss 1134186.9266 | time 100s | total no. of losses 23
# Epoch 1/210 | avg_d_loss 0.6735 | avg_g_loss 1134186.9266
# ---------------- Testing ----------------
# [  0/26] | validation_loss 1267174.5000 | avg_validation_loss 1267174.5000 | time 44s | total no. of losses 1
# [ 10/26] | validation_loss 1107872.7500 | avg_validation_loss 1187523.6250 | time 19s | total no. of losses 2
# [ 20/26] | validation_loss 1081173.6250 | avg_validation_loss 1152073.6250 | time 19s | total no. of losses 3
# Epoch 1/210 | avg_validation loss 1152073.6250 | time 19s | total no. of losses 3
# Generator loss improved from inf to 1152073.625
# Save checkpoint for validation loss of 1152073.625
# Overwrite best checkpoint
# ---------------- Epoch 2 ----------------
# [  0/225] | d_loss 0.0395 | g_loss 1171121.8750 | avg_d_loss 0.0395 | avg_g_loss 1171121.8750 | time 19s | total no. of losses 1
# [ 10/225] | d_loss 0.0346 | g_loss 1108479.6250 | avg_d_loss 0.0371 | avg_g_loss 1139800.7500 | time 83s | total no. of losses 2
# [ 20/225] | d_loss 0.0422 | g_loss 1274440.2500 | avg_d_loss 0.0388 | avg_g_loss 1184680.5833 | time 81s | total no. of losses 3
# [ 30/225] | d_loss 0.0267 | g_loss 1036247.5625 | avg_d_loss 0.0358 | avg_g_loss 1147572.3281 | time 83s | total no. of losses 4
# [ 40/225] | d_loss 0.1131 | g_loss 1219900.7500 | avg_d_loss 0.0512 | avg_g_loss 1162038.0125 | time 83s | total no. of losses 5
# [ 50/225] | d_loss 0.3672 | g_loss 1003943.6250 | avg_d_loss 0.1039 | avg_g_loss 1135688.9479 | time 83s | total no. of losses 6
# [ 60/225] | d_loss 0.0850 | g_loss 1136460.2500 | avg_d_loss 0.1012 | avg_g_loss 1135799.1339 | time 83s | total no. of losses 7
# [ 70/225] | d_loss 0.0644 | g_loss 1101107.3750 | avg_d_loss 0.0966 | avg_g_loss 1131462.6641 | time 82s | total no. of losses 8
# [ 80/225] | d_loss 0.0748 | g_loss 1192956.0000 | avg_d_loss 0.0942 | avg_g_loss 1138295.2569 | time 83s | total no. of losses 9
# [ 90/225] | d_loss 0.0409 | g_loss 1097716.0000 | avg_d_loss 0.0888 | avg_g_loss 1134237.3313 | time 81s | total no. of losses 10
# [100/225] | d_loss 0.0425 | g_loss 1136564.0000 | avg_d_loss 0.0846 | avg_g_loss 1134448.8466 | time 83s | total no. of losses 11
# [110/225] | d_loss 0.0408 | g_loss 1113459.5000 | avg_d_loss 0.0810 | avg_g_loss 1132699.7344 | time 83s | total no. of losses 12
# [120/225] | d_loss 0.0259 | g_loss 1310425.5000 | avg_d_loss 0.0767 | avg_g_loss 1146370.9471 | time 83s | total no. of losses 13
# [130/225] | d_loss 0.0232 | g_loss 1152940.8750 | avg_d_loss 0.0729 | avg_g_loss 1146840.2277 | time 82s | total no. of losses 14
# [140/225] | d_loss 0.0228 | g_loss 1061300.5000 | avg_d_loss 0.0696 | avg_g_loss 1141137.5792 | time 82s | total no. of losses 15
# [150/225] | d_loss 0.0240 | g_loss 1067584.6250 | avg_d_loss 0.0667 | avg_g_loss 1136540.5195 | time 82s | total no. of losses 16
# [160/225] | d_loss 0.0173 | g_loss 1128396.6250 | avg_d_loss 0.0638 | avg_g_loss 1136061.4669 | time 82s | total no. of losses 17
# [170/225] | d_loss 0.0285 | g_loss 996105.8750 | avg_d_loss 0.0619 | avg_g_loss 1128286.1562 | time 83s | total no. of losses 18
# [180/225] | d_loss 0.0186 | g_loss 1150980.2500 | avg_d_loss 0.0596 | avg_g_loss 1129480.5822 | time 83s | total no. of losses 19
# [190/225] | d_loss 0.0151 | g_loss 1129807.1250 | avg_d_loss 0.0574 | avg_g_loss 1129496.9094 | time 82s | total no. of losses 20
# [200/225] | d_loss 0.0142 | g_loss 1013871.6250 | avg_d_loss 0.0553 | avg_g_loss 1123990.9435 | time 82s | total no. of losses 21
# [210/225] | d_loss 0.0145 | g_loss 1082507.0000 | avg_d_loss 0.0534 | avg_g_loss 1122105.3097 | time 82s | total no. of losses 22
# [220/225] | d_loss 0.0112 | g_loss 1130696.3750 | avg_d_loss 0.0516 | avg_g_loss 1122478.8342 | time 83s | total no. of losses 23
# Epoch 2/210 | avg_d_loss 0.0516 | avg_g_loss 1122478.8342
# ---------------- Testing ----------------
# [  0/26] | validation_loss 1071364.0000 | avg_validation_loss 1071364.0000 | time 35s | total no. of losses 1
# [ 10/26] | validation_loss 1166293.7500 | avg_validation_loss 1118828.8750 | time 19s | total no. of losses 2
# [ 20/26] | validation_loss 1179067.0000 | avg_validation_loss 1138908.2500 | time 19s | total no. of losses 3
# Epoch 2/210 | avg_validation loss 1138908.2500 | time 19s | total no. of losses 3
# Generator loss improved from 1152073.625 to 1138908.25
# Save checkpoint for validation loss of 1138908.25
# Overwrite best checkpoint
# ---------------- Epoch 3 ----------------
# [  0/225] | d_loss 0.0170 | g_loss 1164167.7500 | avg_d_loss 0.0170 | avg_g_loss 1164167.7500 | time 18s | total no. of losses 1
# [ 10/225] | d_loss 0.0133 | g_loss 1122729.2500 | avg_d_loss 0.0151 | avg_g_loss 1143448.5000 | time 81s | total no. of losses 2
# [ 20/225] | d_loss 0.0107 | g_loss 1127716.7500 | avg_d_loss 0.0136 | avg_g_loss 1138204.5833 | time 80s | total no. of losses 3
# [ 30/225] | d_loss 0.0108 | g_loss 1076975.1250 | avg_d_loss 0.0129 | avg_g_loss 1122897.2188 | time 80s | total no. of losses 4
# [ 40/225] | d_loss 0.0089 | g_loss 1104704.5000 | avg_d_loss 0.0121 | avg_g_loss 1119258.6750 | time 81s | total no. of losses 5
# [ 50/225] | d_loss 0.0096 | g_loss 1150158.0000 | avg_d_loss 0.0117 | avg_g_loss 1124408.5625 | time 80s | total no. of losses 6
# [ 60/225] | d_loss 0.0086 | g_loss 1160656.0000 | avg_d_loss 0.0113 | avg_g_loss 1129586.7679 | time 80s | total no. of losses 7
# [ 70/225] | d_loss 0.0101 | g_loss 1072778.1250 | avg_d_loss 0.0111 | avg_g_loss 1122485.6875 | time 81s | total no. of losses 8
# [ 80/225] | d_loss 0.0084 | g_loss 1073153.6250 | avg_d_loss 0.0108 | avg_g_loss 1117004.3472 | time 81s | total no. of losses 9
# [ 90/225] | d_loss 0.0087 | g_loss 1083202.1250 | avg_d_loss 0.0106 | avg_g_loss 1113624.1250 | time 80s | total no. of losses 10
# [100/225] | d_loss 0.0080 | g_loss 1122709.5000 | avg_d_loss 0.0104 | avg_g_loss 1114450.0682 | time 80s | total no. of losses 11
# [110/225] | d_loss 0.0072 | g_loss 995195.6250 | avg_d_loss 0.0101 | avg_g_loss 1104512.1979 | time 81s | total no. of losses 12
# [120/225] | d_loss 0.0081 | g_loss 1034010.0000 | avg_d_loss 0.0100 | avg_g_loss 1099088.9519 | time 80s | total no. of losses 13
# [130/225] | d_loss 0.0077 | g_loss 1120534.2500 | avg_d_loss 0.0098 | avg_g_loss 1100620.7589 | time 80s | total no. of losses 14
# [140/225] | d_loss 0.0074 | g_loss 1059940.3750 | avg_d_loss 0.0096 | avg_g_loss 1097908.7333 | time 80s | total no. of losses 15
# [150/225] | d_loss 0.0067 | g_loss 990576.0625 | avg_d_loss 0.0094 | avg_g_loss 1091200.4414 | time 81s | total no. of losses 16
# [160/225] | d_loss 0.0082 | g_loss 1006241.7500 | avg_d_loss 0.0094 | avg_g_loss 1086202.8713 | time 80s | total no. of losses 17
# [170/225] | d_loss 0.0084 | g_loss 1187780.7500 | avg_d_loss 0.0093 | avg_g_loss 1091846.0868 | time 80s | total no. of losses 18
# [180/225] | d_loss 0.0074 | g_loss 1068280.2500 | avg_d_loss 0.0092 | avg_g_loss 1090605.7796 | time 80s | total no. of losses 19
# [190/225] | d_loss 0.0063 | g_loss 1029747.9375 | avg_d_loss 0.0091 | avg_g_loss 1087562.8875 | time 80s | total no. of losses 20
# [200/225] | d_loss 0.0061 | g_loss 1077534.7500 | avg_d_loss 0.0089 | avg_g_loss 1087085.3571 | time 80s | total no. of losses 21
# [210/225] | d_loss 0.0047 | g_loss 955337.0000 | avg_d_loss 0.0087 | avg_g_loss 1081096.7955 | time 80s | total no. of losses 22
# [220/225] | d_loss 0.0057 | g_loss 1082455.5000 | avg_d_loss 0.0086 | avg_g_loss 1081155.8696 | time 81s | total no. of losses 23
# Epoch 3/210 | avg_d_loss 0.0086 | avg_g_loss 1081155.8696
# ---------------- Testing ----------------
# [  0/26] | validation_loss 1087677.6250 | avg_validation_loss 1087677.6250 | time 34s | total no. of losses 1
# [ 10/26] | validation_loss 1008310.8750 | avg_validation_loss 1047994.2500 | time 19s | total no. of losses 2
# [ 20/26] | validation_loss 1150648.7500 | avg_validation_loss 1082212.4167 | time 19s | total no. of losses 3
# Epoch 3/210 | avg_validation loss 1082212.4167 | time 19s | total no. of losses 3
# Generator loss improved from 1138908.25 to 1082212.4166666667
# Save checkpoint for validation loss of 1082212.4166666667
# Overwrite best checkpoint
# ---------------- Epoch 4 ----------------
# [  0/225] | d_loss 0.0046 | g_loss 1028364.3750 | avg_d_loss 0.0046 | avg_g_loss 1028364.3750 | time 18s | total no. of losses 1
# [ 10/225] | d_loss 0.0068 | g_loss 1138079.5000 | avg_d_loss 0.0057 | avg_g_loss 1083221.9375 | time 80s | total no. of losses 2
# [ 20/225] | d_loss 0.0050 | g_loss 1060611.0000 | avg_d_loss 0.0055 | avg_g_loss 1075684.9583 | time 80s | total no. of losses 3
# [ 30/225] | d_loss 0.0049 | g_loss 1072705.2500 | avg_d_loss 0.0053 | avg_g_loss 1074940.0312 | time 80s | total no. of losses 4
# [ 40/225] | d_loss 0.0044 | g_loss 1263792.6250 | avg_d_loss 0.0051 | avg_g_loss 1112710.5500 | time 80s | total no. of losses 5
# [ 50/225] | d_loss 0.0040 | g_loss 1044777.6250 | avg_d_loss 0.0049 | avg_g_loss 1101388.3958 | time 80s | total no. of losses 6
# [ 60/225] | d_loss 0.0042 | g_loss 1045877.0625 | avg_d_loss 0.0048 | avg_g_loss 1093458.2054 | time 80s | total no. of losses 7
# [ 70/225] | d_loss 0.0053 | g_loss 1026580.8750 | avg_d_loss 0.0049 | avg_g_loss 1085098.5391 | time 80s | total no. of losses 8
# [ 80/225] | d_loss 0.0071 | g_loss 1001594.8750 | avg_d_loss 0.0051 | avg_g_loss 1075820.3542 | time 80s | total no. of losses 9
# [ 90/225] | d_loss 0.0059 | g_loss 1068558.0000 | avg_d_loss 0.0052 | avg_g_loss 1075094.1187 | time 80s | total no. of losses 10
# [100/225] | d_loss 0.0047 | g_loss 901965.1875 | avg_d_loss 0.0052 | avg_g_loss 1059355.1250 | time 80s | total no. of losses 11
# [110/225] | d_loss 0.0057 | g_loss 921156.0000 | avg_d_loss 0.0052 | avg_g_loss 1047838.5312 | time 80s | total no. of losses 12
# [120/225] | d_loss 0.0078 | g_loss 844574.1250 | avg_d_loss 0.0054 | avg_g_loss 1032202.8077 | time 80s | total no. of losses 13
# [130/225] | d_loss 0.0054 | g_loss 805639.6875 | avg_d_loss 0.0054 | avg_g_loss 1016019.7277 | time 80s | total no. of losses 14
# [140/225] | d_loss 2.4681 | g_loss 811816.5625 | avg_d_loss 0.1696 | avg_g_loss 1002406.1833 | time 80s | total no. of losses 15
# [150/225] | d_loss 2.0060 | g_loss 800974.1875 | avg_d_loss 0.2844 | avg_g_loss 989816.6836 | time 80s | total no. of losses 16
# [160/225] | d_loss 1.8810 | g_loss 763951.7500 | avg_d_loss 0.3783 | avg_g_loss 976530.5110 | time 80s | total no. of losses 17
# [170/225] | d_loss 1.7567 | g_loss 850910.8125 | avg_d_loss 0.4549 | avg_g_loss 969551.6389 | time 80s | total no. of losses 18
# [180/225] | d_loss 1.6051 | g_loss 756405.2500 | avg_d_loss 0.5154 | avg_g_loss 958333.4079 | time 80s | total no. of losses 19
# [190/225] | d_loss 1.4848 | g_loss 643768.5000 | avg_d_loss 0.5639 | avg_g_loss 942605.1625 | time 80s | total no. of losses 20
# [200/225] | d_loss 1.5564 | g_loss 806408.4375 | avg_d_loss 0.6111 | avg_g_loss 936119.6042 | time 80s | total no. of losses 21
# [210/225] | d_loss 1.2545 | g_loss 577715.8750 | avg_d_loss 0.6404 | avg_g_loss 919828.5256 | time 80s | total no. of losses 22
# [220/225] | d_loss 1.1829 | g_loss 599873.3125 | avg_d_loss 0.6640 | avg_g_loss 905917.4293 | time 80s | total no. of losses 23
# Epoch 4/210 | avg_d_loss 0.6640 | avg_g_loss 905917.4293
# ---------------- Testing ----------------
# [  0/26] | validation_loss 658500.3750 | avg_validation_loss 658500.3750 | time 34s | total no. of losses 1
# [ 10/26] | validation_loss 603777.3750 | avg_validation_loss 631138.8750 | time 19s | total no. of losses 2
# [ 20/26] | validation_loss 593509.8125 | avg_validation_loss 618595.8542 | time 19s | total no. of losses 3
# Epoch 4/210 | avg_validation loss 618595.8542 | time 19s | total no. of losses 3
# Generator loss improved from 1082212.4166666667 to 618595.8541666666
# Save checkpoint for validation loss of 618595.8541666666
# Overwrite best checkpoint
# ---------------- Epoch 5 ----------------
# [  0/225] | d_loss 0.9571 | g_loss 683376.0000 | avg_d_loss 0.9571 | avg_g_loss 683376.0000 | time 18s | total no. of losses 1
# [ 10/225] | d_loss 0.5712 | g_loss 621207.6250 | avg_d_loss 0.7641 | avg_g_loss 652291.8125 | time 80s | total no. of losses 2
# [ 20/225] | d_loss 0.7983 | g_loss 594839.0625 | avg_d_loss 0.7755 | avg_g_loss 633140.8958 | time 80s | total no. of losses 3
# [ 30/225] | d_loss 0.5131 | g_loss 651989.3125 | avg_d_loss 0.7099 | avg_g_loss 637853.0000 | time 80s | total no. of losses 4
# [ 40/225] | d_loss 0.4816 | g_loss 574057.8125 | avg_d_loss 0.6643 | avg_g_loss 625093.9625 | time 80s | total no. of losses 5
# [ 50/225] | d_loss 0.2877 | g_loss 519990.3438 | avg_d_loss 0.6015 | avg_g_loss 607576.6927 | time 80s | total no. of losses 6
# [ 60/225] | d_loss 0.2124 | g_loss 583117.0000 | avg_d_loss 0.5459 | avg_g_loss 604082.4509 | time 80s | total no. of losses 7
# [ 70/225] | d_loss 0.1471 | g_loss 575469.0000 | avg_d_loss 0.4961 | avg_g_loss 600505.7695 | time 80s | total no. of losses 8
# [ 80/225] | d_loss 0.1511 | g_loss 614072.5000 | avg_d_loss 0.4577 | avg_g_loss 602013.1840 | time 80s | total no. of losses 9
# [ 90/225] | d_loss 0.0797 | g_loss 530292.5625 | avg_d_loss 0.4199 | avg_g_loss 594841.1219 | time 80s | total no. of losses 10
# [100/225] | d_loss 0.0510 | g_loss 534544.7500 | avg_d_loss 0.3864 | avg_g_loss 589359.6335 | time 80s | total no. of losses 11
# [110/225] | d_loss 0.2716 | g_loss 622570.1250 | avg_d_loss 0.3768 | avg_g_loss 592127.1745 | time 80s | total no. of losses 12
# [120/225] | d_loss 0.0904 | g_loss 444595.9375 | avg_d_loss 0.3548 | avg_g_loss 580778.6178 | time 80s | total no. of losses 13
# [130/225] | d_loss 0.0832 | g_loss 499760.0625 | avg_d_loss 0.3354 | avg_g_loss 574991.5781 | time 80s | total no. of losses 14
# [140/225] | d_loss 0.2351 | g_loss 500216.5312 | avg_d_loss 0.3287 | avg_g_loss 570006.5750 | time 80s | total no. of losses 15
# [150/225] | d_loss 0.1923 | g_loss 443735.0312 | avg_d_loss 0.3202 | avg_g_loss 562114.6035 | time 80s | total no. of losses 16
# [160/225] | d_loss 0.0979 | g_loss 485402.6250 | avg_d_loss 0.3071 | avg_g_loss 557602.1342 | time 80s | total no. of losses 17
# [170/225] | d_loss 0.0497 | g_loss 528558.1250 | avg_d_loss 0.2928 | avg_g_loss 555988.5781 | time 80s | total no. of losses 18
# [180/225] | d_loss 0.0689 | g_loss 453365.0625 | avg_d_loss 0.2810 | avg_g_loss 550587.3405 | time 80s | total no. of losses 19
# [190/225] | d_loss 0.0456 | g_loss 458793.9688 | avg_d_loss 0.2692 | avg_g_loss 545997.6719 | time 80s | total no. of losses 20
# [200/225] | d_loss 0.0673 | g_loss 398148.9375 | avg_d_loss 0.2596 | avg_g_loss 538957.2560 | time 80s | total no. of losses 21
# [210/225] | d_loss 0.0303 | g_loss 501182.2188 | avg_d_loss 0.2492 | avg_g_loss 537240.2088 | time 80s | total no. of losses 22
# [220/225] | d_loss 0.0190 | g_loss 448908.5938 | avg_d_loss 0.2392 | avg_g_loss 533399.7038 | time 80s | total no. of losses 23
# Epoch 5/210 | avg_d_loss 0.2392 | avg_g_loss 533399.7038
# ---------------- Testing ----------------
# [  0/26] | validation_loss 827696.2500 | avg_validation_loss 827696.2500 | time 34s | total no. of losses 1
# [ 10/26] | validation_loss 815886.3750 | avg_validation_loss 821791.3125 | time 19s | total no. of losses 2
# [ 20/26] | validation_loss 872537.2500 | avg_validation_loss 838706.6250 | time 19s | total no. of losses 3
# Epoch 5/210 | avg_validation loss 838706.6250 | time 19s | total no. of losses 3
# Save checkpoint for validation loss of 838706.625
# ---------------- Epoch 6 ----------------
# [  0/225] | d_loss 0.0431 | g_loss 537418.5000 | avg_d_loss 0.0431 | avg_g_loss 537418.5000 | time 17s | total no. of losses 1
# [ 10/225] | d_loss 0.0296 | g_loss 495166.3750 | avg_d_loss 0.0364 | avg_g_loss 516292.4375 | time 80s | total no. of losses 2
# [ 20/225] | d_loss 0.0414 | g_loss 458094.0312 | avg_d_loss 0.0380 | avg_g_loss 496892.9688 | time 80s | total no. of losses 3
# [ 30/225] | d_loss 0.0298 | g_loss 404770.4375 | avg_d_loss 0.0360 | avg_g_loss 473862.3359 | time 80s | total no. of losses 4
# [ 40/225] | d_loss 0.0403 | g_loss 393911.8125 | avg_d_loss 0.0368 | avg_g_loss 457872.2313 | time 80s | total no. of losses 5
# [ 50/225] | d_loss 2.7026 | g_loss 385845.6875 | avg_d_loss 0.4811 | avg_g_loss 445867.8073 | time 80s | total no. of losses 6
# [ 60/225] | d_loss 0.0746 | g_loss 430225.9375 | avg_d_loss 0.4230 | avg_g_loss 443633.2545 | time 80s | total no. of losses 7
# [ 70/225] | d_loss 0.0825 | g_loss 399354.6250 | avg_d_loss 0.3805 | avg_g_loss 438098.4258 | time 80s | total no. of losses 8
# [ 80/225] | d_loss 0.2107 | g_loss 384073.6875 | avg_d_loss 0.3616 | avg_g_loss 432095.6771 | time 80s | total no. of losses 9
# [ 90/225] | d_loss 0.0455 | g_loss 394682.0938 | avg_d_loss 0.3300 | avg_g_loss 428354.3187 | time 80s | total no. of losses 10
# [100/225] | d_loss 0.5407 | g_loss 407691.5625 | avg_d_loss 0.3492 | avg_g_loss 426475.8864 | time 80s | total no. of losses 11
# [110/225] | d_loss 0.1567 | g_loss 346338.7188 | avg_d_loss 0.3331 | avg_g_loss 419797.7891 | time 80s | total no. of losses 12
# [120/225] | d_loss 0.0381 | g_loss 388831.0312 | avg_d_loss 0.3104 | avg_g_loss 417415.7308 | time 80s | total no. of losses 13
# [130/225] | d_loss 0.0455 | g_loss 397386.1875 | avg_d_loss 0.2915 | avg_g_loss 415985.0491 | time 80s | total no. of losses 14
# [140/225] | d_loss 0.0451 | g_loss 421541.5938 | avg_d_loss 0.2751 | avg_g_loss 416355.4854 | time 80s | total no. of losses 15
# [150/225] | d_loss 0.0261 | g_loss 341642.4375 | avg_d_loss 0.2595 | avg_g_loss 411685.9199 | time 80s | total no. of losses 16
# [160/225] | d_loss 0.0230 | g_loss 401330.3750 | avg_d_loss 0.2456 | avg_g_loss 411076.7702 | time 80s | total no. of losses 17
# [170/225] | d_loss 0.4877 | g_loss 346802.8750 | avg_d_loss 0.2591 | avg_g_loss 407505.9983 | time 80s | total no. of losses 18
# [180/225] | d_loss 0.0339 | g_loss 390584.8750 | avg_d_loss 0.2472 | avg_g_loss 406615.4128 | time 80s | total no. of losses 19

# %%
# %matplotlib inline
# %config InlineBackend.figure.format = 'retina'

import matplotlib.pyplot as plt

d_losses = [x[0] for x in losses]
g_losses = [x[1] for x in losses]
plt.plot(d_losses, label='Discriminator training loss')
plt.plot(g_losses, label='Generator training loss')
plt.plot(validation_losses, label='Generator validation loss')
plt.legend(frameon=False)

# %% [markdown]
# ### Show results in tensorboard

# %%
# %load_ext tensorboard
# %tensorboard --logdir='/content/data/My Drive/cartoonGAN/tensorboard'

# %% [markdown]
# ##Test
# Bug: It seems that I make a mistake somewhere in the saving logic of the best checkpoint. The best checkpoint seems not to be the best comic-stlye looking result if compared with the model trained after 210 epochs. Therefore see both results tested below.

# %%
checkpoint = torch.load(checkpoint_dir + '/best_checkpoint.pth', map_location=torch.device(device))
G_inference = Generator()
G_inference.load_state_dict(checkpoint['g_state_dict'])

# %%
test_images = iter(photo_dataloader_valid).next()[0]
result_images_best_checkpoint = G_inference(test_images)
result_images_checkpoint_after_210_epochs = G(test_images)
print(result_images_best_checkpoint[0])
plt.imshow(np.transpose(result_images_best_checkpoint[0].detach().numpy(), (1, 2, 0)))

# %%
plt.imshow(np.transpose(result_images_checkpoint_after_210_epochs[0].detach().numpy(), (1, 2, 0)))

# %% [markdown]
# ### Save weights for production release
# In order to have a small file size for a production release, save only the weights of the generator to get a smaller artifact.
#
# This should be the weights of the best checkpoint, but due to the bug described above, I take the latest version of the generator.
#
# Filesize comparison:
#
# Full checkpoint with Generator, Discriminator, Optimizer: 140MB
#
# Generator only: 43MB

# %%
generator_release = {'last_epoch': epoch+1,
                    'g_state_dict': G.state_dict(),
                   }
print("Save generator release")
torch.save(generator_release, checkpoint_dir + '/generator_release.pth')
